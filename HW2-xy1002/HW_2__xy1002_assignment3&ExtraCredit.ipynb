# %%
## from Lab2 
import os
import numpy as np
from numpy.random import randn
import pylab as pl
import datetime as dt


from pandas import Series, DataFrame
import pandas
import pandas as pd

DFDATA = os.getenv("DFDATA")
print (DFDATA)
# Out:
# /gws/open/NYCOpenData/nycopendata/data

# %%
fin = open(DFDATA + "/wng2-85mv/1414246045/wng2-85mv", "r")

# %%
## from UInotebooks/dataWrangling/readingData.ipynb
df_xy1002 = pd.read_csv(DFDATA + "/wng2-85mv/1414246045/wng2-85mv")
df_xy1002.columns
# Out:
# Index(['ID', 'GIS ID', 'Roadway Name', 'From', 'To', 'Direction', 'Date',
#        '12:00-1:00 AM', '1:00-2:00AM', '2:00-3:00AM', '3:00-4:00AM',
#        '4:00-5:00AM', '5:00-6:00AM', '6:00-7:00AM', '7:00-8:00AM',
#        '8:00-9:00AM', '9:00-10:00AM', '10:00-11:00AM', '11:00-12:00PM',
#        '12:00-1:00PM', '1:00-2:00PM', '2:00-3:00PM', '3:00-4:00PM',
#        '4:00-5:00PM', '5:00-6:00PM', '6:00-7:00PM', '7:00-8:00PM',
#        '8:00-9:00PM', '9:00-10:00PM', '10:00-11:00PM', '11:00-12:00AM'],
#       dtype='object')

# %%
## from UInotebooks/dataWrangling/readingData.ipynb
# %pylab inline

np.set_printoptions(precision=4, threshold=500)
np.random.seed(123321)
pl.rc('figure', figsize=(10, 6))
pd.options.display.max_rows = 10

df_xy1002
# Out:
# Populating the interactive namespace from numpy and matplotlib
#         ID  GIS ID      Roadway Name         From                To Direction  \
# 0        1   15540      BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 1        2   15540      BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 2        3   15540      BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 3        4   15540      BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 4        5   15540      BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# ...    ...     ...               ...          ...               ...       ...
# 3388  3389    7886  WILLOWBROOK ROAD  SENECA LOOP  COLLFIELD AVENUE        WB
# 3389  3390    7886  WILLOWBROOK ROAD  SENECA LOOP  COLLFIELD AVENUE        WB
# 3390  3391    7886  WILLOWBROOK ROAD  SENECA LOOP  COLLFIELD AVENUE        WB
# 3391  3392    7886  WILLOWBROOK ROAD  SENECA LOOP  COLLFIELD AVENUE        WB
# ...

# %%
## from UInotebooks/dataWrangling/readingData.ipynb
df_xy1002BeachStreet = df_xy1002[df_xy1002['Roadway Name'].str.contains("MANOR RD")]
df_xy1002BeachStreet
# Out:
#       ID  GIS ID Roadway Name         From            To Direction       Date  \
# 78    79   12370     MANOR RD  SCHMIDTS LA  WESTWOOD AVE        NB 2012-01-09
# 79    80   12370     MANOR RD  SCHMIDTS LA  WESTWOOD AVE        NB 2012-01-10
# 80    81   12370     MANOR RD  SCHMIDTS LA  WESTWOOD AVE        NB 2012-01-11
# 81    82   12370     MANOR RD  SCHMIDTS LA  WESTWOOD AVE        NB 2012-01-12
# 82    83   12370     MANOR RD  SCHMIDTS LA  WESTWOOD AVE        NB 2012-01-13
# ..   ...     ...          ...          ...           ...       ...        ...
# 97    98   11273     MANOR RD   LINCOLN ST     CROAK AVE        NB 2012-01-10
# 98    99   11273     MANOR RD   LINCOLN ST     CROAK AVE        NB 2012-01-11
# 99   100   11273     MANOR RD   LINCOLN ST     CROAK AVE        NB 2012-01-12
# 100  101   11273     MANOR RD   LINCOLN ST     CROAK AVE        NB 2012-01-13
# 101  102   11273     MANOR RD   LINCOLN ST     CROAK AVE        NB 2012-01-14
#
# ...

# %%
## from UInotebooks/dataWrangling/readingData.ipynb
df1 = df_xy1002BeachStreet.drop(['ID', 'GIS ID', 'Roadway Name', 'From', 'To', 'Direction','Date',
       '12:00-1:00 AM', '1:00-2:00AM', '2:00-3:00AM', '3:00-4:00AM',
       '4:00-5:00AM', '5:00-6:00AM', '6:00-7:00AM', '7:00-8:00AM', '10:00-11:00AM', '11:00-12:00PM',
       '12:00-1:00PM', '1:00-2:00PM', '2:00-3:00PM', '3:00-4:00PM',
       '4:00-5:00PM', '5:00-6:00PM', '6:00-7:00PM', '7:00-8:00PM',
       '8:00-9:00PM', '9:00-10:00PM', '10:00-11:00PM', '11:00-12:00AM'],axis = 1)
df1
# Out:
#      8:00-9:00AM  9:00-10:00AM
# 78           386           286
# 79           373           255
# 80           382           263
# 81           413           250
# 82           395           261
# ..           ...           ...
# 97           338           230
# 98           332           247
# 99           362           219
# 100          369           236
# 101          158           195
#
# [24 rows x 2 columns]

# %%
## from UInotebooks/dataWrangling/readingData.ipynb
ax1 = df1.plot.scatter(x='8:00-9:00AM', y='9:00-10:00AM', alpha=0.2)
ax1.set_title("Traffic Volumn corelation between 8-9am and 9-10am")

# %%
## from UInotebooks/dataWrangling/readingData.ipynb
df2 = df_xy1002BeachStreet.drop(['ID', 'GIS ID', 'Roadway Name', 'From', 'To', 'Direction',
       '12:00-1:00 AM', '1:00-2:00AM', '2:00-3:00AM', '3:00-4:00AM',
       '4:00-5:00AM', '5:00-6:00AM', '6:00-7:00AM', '7:00-8:00AM', '9:00-10:00AM','10:00-11:00AM', '11:00-12:00PM',
       '12:00-1:00PM', '1:00-2:00PM', '2:00-3:00PM', '3:00-4:00PM',
       '4:00-5:00PM', '5:00-6:00PM', '6:00-7:00PM', '7:00-8:00PM',
       '8:00-9:00PM', '9:00-10:00PM', '10:00-11:00PM', '11:00-12:00AM'],axis = 1)
df2.head()
# Out:
#          Date  8:00-9:00AM
# 78 2012-01-09          386
# 79 2012-01-10          373
# 80 2012-01-11          382
# 81 2012-01-12          413
# 82 2012-01-13          395

# %%
## from UInotebooks/dataWrangling/readingData.ipynb
import datetime

df2['Date'] = pd.to_datetime(df2['Date'])
ax2 = df2.plot.scatter(x='Date', y='8:00-9:00AM', style = 'o', alpha=0.2)
ax2.set_title("Traffic Volumn corelation between date and time")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...
